# %%
##IMPORT LIBRARIES
import pandas as pd
import numpy as np

from glob import glob
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
from PIL import Image

# %%
##IMPORT CV2
import cv2

# %%
##LOAD A IMAGE
img = cv2.imread('/content/CMS 003821.jpg')

# %%
##USING IF ELSE CONDITON iMAGE IS SUCSESSSFULLY LOADED OR NOT
if img is None:
    print("Error: Unable to load image.")
else:
    print("Image loaded successfully.")
# Out:
# Image loaded successfully.

# %%
##SHUOWED IMAGE USING MATPLOTLIB AS PLT
plt.imshow(img)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
##IMAGE TYPE CHANGED INTO STRING
img = str(img)

# %%
img = str(img)

# %%
##IMAGE IS SPLITED WITH'/' AND '.'
img = img.split('/')[-1].split('.')

# %%
print(img)
# Out:
# ['[[[255 255 255]\n  [255 255 255]\n  [255 255 255]\n  ', '', '', '\n  [255 255 255]\n  [255 255 255]\n  [255 255 255]]\n\n [[255 255 255]\n  [255 255 255]\n  [255 255 255]\n  ', '', '', '\n  [255 255 255]\n  [255 255 255]\n  [255 255 255]]\n\n [[255 255 255]\n  [255 255 255]\n  [255 255 255]\n  ', '', '', '\n  [255 255 255]\n  [255 255 255]\n  [255 255 255]]\n\n ', '', '', '\n\n [[255 255 255]\n  [255 255 255]\n  [255 255 255]\n  ', '', '', '\n  [255 255 255]\n  [255 255 255]\n  [255 255 255]]\n\n [[255 255 255]\n  [255 255 255]\n  [255 255 255]\n  ', '', '', '\n  [255 255 255]\n  [255 255 255]\n  [255 255 255]]\n\n [[255 255 255]\n  [255 255 255]\n  [255 255 255]\n  ', '', '', '\n  [255 255 255]\n  [255 255 255]\n  [255 255 255]]]']

# %%
##INSTALL PYTESSERACT
# !pip install pytesseract

# %%
##IMPORT PYTESSERACT
import pytesseract
from PIL import Image
# !pip install Pillow
# !sudo apt install tesseract-ocr
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
##OPEN IMAGE IN JPG
img = Image.open("/content/CMS 003821.jpg")

# %%
##USING PYTESSERACT CONVERTED IMAGE TO STRING
text = pytesseract.image_to_string(img, lang='eng')

# %%
print(text)
# Out:
#
#
#
#
# TAX INVOICE
#
# ‘
#
#
#
# ~
#
# CMS Connecting Commerce
# \
#
# 4021 ccb1dad93105f8ecB94d72b995t7a87 b9cbeda7d63aa48fe90f260td4 17 - 182211415731136 - 3/3/2022 5:12:00 PM
#
#
#
# Bill From
# CMS INFO SYSTEMS LIMITED
# 1st Floor, Plot no. 159/B, Nayapalli,, ,
#
# Ship To :
# INDUSIND BANK LIMITED,
# Gr.Fl, Plot.No -1320, Bajrakabati,Road ,Cuttack,
#
# Bill To
# INDUSIND BANK LIMITED
# Gr.Fl, Plot.No -1320, Sajrakabati,Road, Cuttack,,
#
#
#
#
#
# Bhubaneswar - 751012
# TELEPHONE :
#
# E-Mail:
#
#
#
# Cuttack ,
#
#
#
# Cuttack - 753001
#
#
#
#
#
#
# Contact Name :
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# £-Mail:
#
# GSTN : 21AAACI1314G1ZF > 2TAAACII314G1ZF GSTN 3 zraamcszartnrzuf/
# State =: Orissa ~ State : Orissa State > Orissa
#
# Code : 21 Code : 21 Code : 21
#
#
#
#
#
# AAMCS2311K
#
#
#
# AAACI1314G6 AAACI1314G
#
#
#
#
#
#
# " INVOICE TYPE ORIGINAL FOR RECIPIENT
#
#
#
# INVOICE NUMBER : °2122/C/OR/003821 §
#
# P.O. NUMBER INVOICE DATE : 03/03/2022 f
# AGREEMENT CODE P.O. DATE’ ;
# ...

# %% [markdown]
# KERAS_OCR

# %%
##install keras_ocr
# !pip install keras-ocr -q

# %%
# !pip show keras-ocr
# Out:
# Name: keras-ocr
# Version: 0.9.3
# Summary: A packaged and flexible version of the CRAFT text detector and Keras CRNN recognition model.
# Home-page: https://github.com/faustomorales/keras-ocr
# Author: Fausto Morales
# Author-email: faustomorales@gmail.com
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: editdistance, efficientnet, essential_generators, fonttools, imgaug, pyclipper, shapely, tqdm, validators
# Required-by:

# %%
import keras_ocr

print(dir(keras_ocr))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'config', 'data_generation', 'datasets', 'detection', 'evaluation', 'pipeline', 'recognition', 'tools']

# %% [markdown]
# # ***JSON file***

# %%
import json
import pytesseract
from PIL import Image

# Load the image
img = Image.open('/content/CMS 003821.jpg')

# Use pytesseract to extract text from the image
text = pytesseract.image_to_string(img, lang='eng')

# Create a dictionary to store the text
text_dict = {
    "text": text
}

# Write the dictionary to a JSON file
with open('output.json', 'w') as json_file:
    json.dump(text_dict, json_file, indent=4)

# %%
from google.colab import files

# %%
# !pip install google-api-python-client

# %%
from googleapiclient.discovery import build

# %%
drive_service = build('drive', 'v3')

# %%
files = drive_service.files()
